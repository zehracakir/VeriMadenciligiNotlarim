# %%
import pandas as pd

# %%
fish=pd.read_csv("resources/resources/Fish.csv")
fish.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
fish.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  159 non-null    object
#  1   Weight   159 non-null    float64
#  2   Length1  159 non-null    float64
#  3   Length2  159 non-null    float64
#  4   Length3  159 non-null    float64
#  5   Height   159 non-null    float64
#  6   Width    159 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.8+ KB

# %%
fish.describe().T
# Out:
#          count        mean         std     min        25%       50%       75%  \
# Weight   159.0  398.326415  357.978317  0.0000  120.00000  273.0000  650.0000
# Length1  159.0   26.247170    9.996441  7.5000   19.05000   25.2000   32.7000
# Length2  159.0   28.415723   10.716328  8.4000   21.00000   27.3000   35.5000
# Length3  159.0   31.227044   11.610246  8.8000   23.15000   29.4000   39.6500
# Height   159.0    8.970994    4.286208  1.7284    5.94480    7.7860   12.3659
# Width    159.0    4.417486    1.685804  1.0476    3.38565    4.2485    5.5845
#
#               max
# Weight   1650.000
# Length1    59.000
# Length2    63.400
# Length3    68.000
# Height     18.957
# Width       8.142

# %%
a=fish[fish["Weight"]==0].index

# %%
fish.drop(a,inplace=True)

# %%
fish.describe().T
# Out:
#          count        mean         std     min        25%        50%  \
# Weight   158.0  400.847468  357.697796  5.9000  121.25000  281.50000
# Length1  158.0   26.293038   10.011427  7.5000   19.15000   25.30000
# Length2  158.0   28.465823   10.731707  8.4000   21.00000   27.40000
# Length3  158.0   31.280380   11.627605  8.8000   23.20000   29.70000
# Height   158.0    8.986790    4.295191  1.7284    5.94060    7.78900
# Width    158.0    4.424232    1.689010  1.0476    3.39865    4.27705
#
#                75%       max
# Weight   650.00000  1650.000
# Length1   32.70000    59.000
# Length2   35.75000    63.400
# Length3   39.67500    68.000
# Height    12.37185    18.957
# Width      5.58675     8.142

# %%
import matplotlib.pyplot as plt

# %%
fish.columns
# Out:
# Index(['Species', 'Weight', 'Length1', 'Length2', 'Length3', 'Height',
#        'Width'],
#       dtype='object')

# %%
df_X=fish.drop("Weight",axis=1)
df_y=fish["Weight"]
fish=df_X.join(df_y)
fish
# Out:
#     Species  Length1  Length2  Length3   Height   Width  Weight
# 0     Bream     23.2     25.4     30.0  11.5200  4.0200   242.0
# 1     Bream     24.0     26.3     31.2  12.4800  4.3056   290.0
# 2     Bream     23.9     26.5     31.1  12.3778  4.6961   340.0
# 3     Bream     26.3     29.0     33.5  12.7300  4.4555   363.0
# 4     Bream     26.5     29.0     34.0  12.4440  5.1340   430.0
# ..      ...      ...      ...      ...      ...     ...     ...
# 154   Smelt     11.5     12.2     13.4   2.0904  1.3936    12.2
# 155   Smelt     11.7     12.4     13.5   2.4300  1.2690    13.4
# 156   Smelt     12.1     13.0     13.8   2.2770  1.2558    12.2
# 157   Smelt     13.2     14.3     15.2   2.8728  2.0672    19.7
# 158   Smelt     13.8     15.0     16.2   2.9322  1.8792    19.9
#
# [158 rows x 7 columns]

# %%
fish.corr()
# Out:
#           Length1   Length2   Length3    Height     Width    Weight
# Length1  1.000000  0.999516  0.992004  0.624409  0.866684  0.915719
# Length2  0.999516  1.000000  0.994083  0.639503  0.873201  0.918603
# Length3  0.992004  0.994083  1.000000  0.702655  0.878189  0.923090
# Height   0.624409  0.639503  0.702655  1.000000  0.792401  0.723857
# Width    0.866684  0.873201  0.878189  0.792401  1.000000  0.886654
# Weight   0.915719  0.918603  0.923090  0.723857  0.886654  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(14,8))
sns.heatmap(fish.corr(),annot=True,cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
fish.hist(figsize=(14,8))
# Out:
# array([[<AxesSubplot:title={'center':'Length1'}>,
#         <AxesSubplot:title={'center':'Length2'}>],
#        [<AxesSubplot:title={'center':'Length3'}>,
#         <AxesSubplot:title={'center':'Height'}>],
#        [<AxesSubplot:title={'center':'Width'}>,
#         <AxesSubplot:title={'center':'Weight'}>]], dtype=object)

# %%
import numpy as np
fish["Length1"]=np.log(fish["Length1"])+1
fish["Length2"]=np.log(fish["Length2"])+1
fish["Length3"]=np.log(fish["Length3"])+1

# %%
fish.hist(figsize=(14,8))
# Out:
# array([[<AxesSubplot:title={'center':'Length1'}>,
#         <AxesSubplot:title={'center':'Length2'}>],
#        [<AxesSubplot:title={'center':'Length3'}>,
#         <AxesSubplot:title={'center':'Height'}>],
#        [<AxesSubplot:title={'center':'Width'}>,
#         <AxesSubplot:title={'center':'Weight'}>]], dtype=object)

# %%
plt.figure(figsize=(14,8))
sns.heatmap(fish.corr(),annot=True,cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
fish.drop(["Length1","Length2"],axis=1,inplace=True)
fish
# Out:
#     Species   Length3   Height   Width  Weight
# 0     Bream  4.401197  11.5200  4.0200   242.0
# 1     Bream  4.440418  12.4800  4.3056   290.0
# 2     Bream  4.437208  12.3778  4.6961   340.0
# 3     Bream  4.511545  12.7300  4.4555   363.0
# 4     Bream  4.526361  12.4440  5.1340   430.0
# ..      ...       ...      ...     ...     ...
# 154   Smelt  3.595255   2.0904  1.3936    12.2
# 155   Smelt  3.602690   2.4300  1.2690    13.4
# 156   Smelt  3.624669   2.2770  1.2558    12.2
# 157   Smelt  3.721295   2.8728  2.0672    19.7
# 158   Smelt  3.785011   2.9322  1.8792    19.9
#
# [158 rows x 5 columns]

# %%
fish["Species"].unique()
# Out:
# array(['Bream', 'Roach', 'Whitefish', 'Parkki', 'Perch', 'Pike', 'Smelt'],
#       dtype=object)

# %%
a=pd.get_dummies(fish.Species)

# %%
fish=fish.join(a)
fish
# Out:
#     Species   Length3   Height   Width  Weight  Bream  Parkki  Perch  Pike  \
# 0     Bream  4.401197  11.5200  4.0200   242.0      1       0      0     0
# 1     Bream  4.440418  12.4800  4.3056   290.0      1       0      0     0
# 2     Bream  4.437208  12.3778  4.6961   340.0      1       0      0     0
# 3     Bream  4.511545  12.7300  4.4555   363.0      1       0      0     0
# 4     Bream  4.526361  12.4440  5.1340   430.0      1       0      0     0
# ..      ...       ...      ...     ...     ...    ...     ...    ...   ...
# 154   Smelt  3.595255   2.0904  1.3936    12.2      0       0      0     0
# 155   Smelt  3.602690   2.4300  1.2690    13.4      0       0      0     0
# 156   Smelt  3.624669   2.2770  1.2558    12.2      0       0      0     0
# 157   Smelt  3.721295   2.8728  2.0672    19.7      0       0      0     0
# 158   Smelt  3.785011   2.9322  1.8792    19.9      0       0      0     0
#
#      Roach  Smelt  Whitefish
# 0        0      0          0
# ...

# %%
df_X=fish.drop("Weight",axis=1)
df_y=fish["Weight"]
fish=df_X.join(df_y)
fish
# Out:
#     Species   Length3   Height   Width  Bream  Parkki  Perch  Pike  Roach  \
# 0     Bream  4.401197  11.5200  4.0200      1       0      0     0      0
# 1     Bream  4.440418  12.4800  4.3056      1       0      0     0      0
# 2     Bream  4.437208  12.3778  4.6961      1       0      0     0      0
# 3     Bream  4.511545  12.7300  4.4555      1       0      0     0      0
# 4     Bream  4.526361  12.4440  5.1340      1       0      0     0      0
# ..      ...       ...      ...     ...    ...     ...    ...   ...    ...
# 154   Smelt  3.595255   2.0904  1.3936      0       0      0     0      0
# 155   Smelt  3.602690   2.4300  1.2690      0       0      0     0      0
# 156   Smelt  3.624669   2.2770  1.2558      0       0      0     0      0
# 157   Smelt  3.721295   2.8728  2.0672      0       0      0     0      0
# 158   Smelt  3.785011   2.9322  1.8792      0       0      0     0      0
#
#      Smelt  Whitefish  Weight
# 0        0          0   242.0
# ...

# %%
fish.drop("Species",axis=1,inplace=True)
fish
# Out:
#       Length3   Height   Width  Bream  Parkki  Perch  Pike  Roach  Smelt  \
# 0    4.401197  11.5200  4.0200      1       0      0     0      0      0
# 1    4.440418  12.4800  4.3056      1       0      0     0      0      0
# 2    4.437208  12.3778  4.6961      1       0      0     0      0      0
# 3    4.511545  12.7300  4.4555      1       0      0     0      0      0
# 4    4.526361  12.4440  5.1340      1       0      0     0      0      0
# ..        ...      ...     ...    ...     ...    ...   ...    ...    ...
# 154  3.595255   2.0904  1.3936      0       0      0     0      0      1
# 155  3.602690   2.4300  1.2690      0       0      0     0      0      1
# 156  3.624669   2.2770  1.2558      0       0      0     0      0      1
# 157  3.721295   2.8728  2.0672      0       0      0     0      0      1
# 158  3.785011   2.9322  1.8792      0       0      0     0      0      1
#
#      Whitefish  Weight
# 0            0   242.0
# 1            0   290.0
# ...

# %%
plt.figure(figsize=(14,8))
sns.heatmap(fish.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df_X=fish.drop("Weight",axis=1)
df_y=fish["Weight"]
fish=df_X.join(df_y)
fish
# Out:
#       Length3   Height   Width  Bream  Parkki  Perch  Pike  Roach  Smelt  \
# 0    4.401197  11.5200  4.0200      1       0      0     0      0      0
# 1    4.440418  12.4800  4.3056      1       0      0     0      0      0
# 2    4.437208  12.3778  4.6961      1       0      0     0      0      0
# 3    4.511545  12.7300  4.4555      1       0      0     0      0      0
# 4    4.526361  12.4440  5.1340      1       0      0     0      0      0
# ..        ...      ...     ...    ...     ...    ...   ...    ...    ...
# 154  3.595255   2.0904  1.3936      0       0      0     0      0      1
# 155  3.602690   2.4300  1.2690      0       0      0     0      0      1
# 156  3.624669   2.2770  1.2558      0       0      0     0      0      1
# 157  3.721295   2.8728  2.0672      0       0      0     0      0      1
# 158  3.785011   2.9322  1.8792      0       0      0     0      0      1
#
#      Whitefish  Weight
# 0            0   242.0
# 1            0   290.0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(df_X,df_y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([-236.650661  ,   61.16572825,  150.87549098, -296.89360267,
#        -153.73496737,  -49.63262935,  384.08385861,  -63.50100408,
#         264.65879128,  -84.98044642])

# %%
model.intercept_
# Out:
# 257.73163139237704

# %%
y_predict=model.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_predict)
# Out:
# 0.9497040254336148

# %%
sns.regplot(x=y_test,y=y_predict)
# Out:
# <AxesSubplot:xlabel='Weight'>

# %%
y_predict
# Out:
# array([ 522.03851409,   98.1274022 ,  591.91059312,  129.35011896,
#         124.31908532,  992.05815601,  172.04321514,  145.53645185,
#         212.80405359, 1144.90724203,  608.48548949,  368.22836812,
#         654.54726132,  382.21123252,  684.87693765,  882.82538992,
#         891.91888994,  711.20550714,   80.7481166 ,  142.53302695,
#           6.03813799,  590.41122696,  374.14592388,  493.26641431,
#         884.08600835,  119.18116356,  380.49355527,  933.45725204,
#        1064.7589102 ,  -15.30795636,    1.34217073,    5.38458656])

# %%
y_test
# Out:
# 129     300.0
# 46      140.0
# 135     510.0
# 157      19.7
# 91      130.0
# 29     1000.0
# 97      145.0
# 99      180.0
# 96      225.0
# 141    1250.0
# 19      650.0
# 57      306.0
# 15      600.0
# 70      273.0
# 24      700.0
# 30      920.0
# 123    1100.0
# 110     556.0
# 94      150.0
# 66      140.0
# 151      10.0
# 18      610.0
# 12      500.0
# 9       500.0
# 31      955.0
# 82      110.0
# 52      290.0
# 140     950.0
# 126    1000.0
# 147       7.0
# 146       7.5
# 76       70.0
# Name: Weight, dtype: float64
