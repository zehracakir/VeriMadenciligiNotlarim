# %%
import pandas as pd

# %%
emp_df=pd.read_csv("resources/resources/employees.csv")
emp_df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
emp_df.info() #df hakkında genel bilgileri verir
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
pd.to_datetime(emp_df["Start Date"]) # Bir alana datetime türüne dönüştürme
# Out:
# 0     1993-08-06
# 1     1996-03-31
# 2     1993-04-23
# 3     2005-03-04
# 4     1998-01-24
#          ...
# 995   2014-11-23
# 996   1984-01-31
# 997   2013-05-20
# 998   2013-04-20
# 999   2012-05-15
# Name: Start Date, Length: 1000, dtype: datetime64[ns]

# %%
emp_df["Start Date"]=pd.to_datetime(emp_df["Start Date"]) #değişikliklerin kalıcı olması için
emp_df
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42 PM   97308    6.945
# 1       Thomas    Male 1996-03-31         6:53 AM   61933    4.170
# 2        Maria  Female 1993-04-23        11:17 AM  130590   11.858
# 3        Jerry    Male 2005-03-04         1:00 PM  138705    9.340
# 4        Larry    Male 1998-01-24         4:47 PM  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 995      Henry     NaN 2014-11-23         6:09 AM  132483   16.655
# 996    Phillip    Male 1984-01-31         6:30 AM   42392   19.675
# 997    Russell    Male 2013-05-20        12:39 PM   96914    1.421
# 998      Larry    Male 2013-04-20         4:45 PM   60500   11.985
# 999     Albert    Male 2012-05-15         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
emp_df["Last Login Time"]=pd.to_datetime(emp_df["Last Login Time"])
emp_df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-12-29 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2022-12-29 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2022-12-29 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-12-29 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-12-29 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2022-12-29 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2022-12-29 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2022-12-29 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2022-12-29 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2022-12-29 18:24:00  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# ...

# %%
emp_df["Senior Management"]=emp_df["Senior Management"].astype(bool) # Bir alanı boolean a dönüştürme
emp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), datetime64[ns](2), float64(1), int64(1), object(3)
# memory usage: 55.8+ KB

# %%
emp_df["Gender"]=emp_df["Gender"].astype("category")
emp_df.info() #62kb den 49 kb ye düştü alan kazancımız oldu
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.1+ KB

# %%
emp_df.drop('Last Login Time', axis=1, inplace=True) #belirtilen sütunu silmek
emp_df
# Out:
#     First Name  Gender Start Date  Salary  Bonus %  Senior Management  \
# 0      Douglas    Male 1993-08-06   97308    6.945               True
# 1       Thomas    Male 1996-03-31   61933    4.170               True
# 2        Maria  Female 1993-04-23  130590   11.858              False
# 3        Jerry    Male 2005-03-04  138705    9.340               True
# 4        Larry    Male 1998-01-24  101004    1.389               True
# ..         ...     ...        ...     ...      ...                ...
# 995      Henry     NaN 2014-11-23  132483   16.655              False
# 996    Phillip    Male 1984-01-31   42392   19.675              False
# 997    Russell    Male 2013-05-20   96914    1.421              False
# 998      Larry    Male 2013-04-20   60500   11.985              False
# 999     Albert    Male 2012-05-15  129949   10.169               True
#
#                      Team
# 0               Marketing
# 1                     NaN
# 2                 Finance
# ...

# %%
emp_df=pd.read_csv("resources/resources/employees.csv")
#pd.to_datetime(emp_df["Start Date"]) #start date i datetime yaptık daha önce object stringti 
emp_df["Start Date"]=pd.to_datetime(emp_df["Start Date"]) #değişikliklerin kalıcı olması için
emp_df["Last Login Time"]=pd.to_datetime(emp_df["Last Login Time"])
emp_df["Senior Management"]=emp_df["Senior Management"].astype(bool)
emp_df["Gender"]=emp_df["Gender"].astype("category")
emp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.1+ KB

# %%
emp_df=pd.read_csv("resources/resources/employees.csv",parse_dates=["Start Date","Last Login Time"]) 
#parse_dates->datetime olanları bizim için oto olarak parse eder
#pd.to_datetime(emp_df["Start Date"]) #start date i datetime yaptık daha önce object stringti 
#emp_df["Start Date"]=pd.to_datetime(emp_df["Start Date"]) #değişikliklerin kalıcı olması için
#emp_df["Last Login Time"]=pd.to_datetime(emp_df["Last Login Time"])
emp_df["Senior Management"]=emp_df["Senior Management"].astype(bool)
emp_df["Gender"]=emp_df["Gender"].astype("category")
emp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.1+ KB

# %%
emp_df[emp_df["Gender"]=="Male"] #male olanları getirir
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2022-12-29 12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31 2022-12-29 06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04 2022-12-29 13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24 2022-12-29 16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18 2022-12-29 01:35:00  115163   10.125
# ..         ...    ...        ...                 ...     ...      ...
# 994     George   Male 2013-06-21 2022-12-29 17:47:00   98874    4.479
# 996    Phillip   Male 1984-01-31 2022-12-29 06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20 2022-12-29 12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20 2022-12-29 16:45:00   60500   11.985
# 999     Albert   Male 2012-05-15 2022-12-29 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
emp_df[emp_df["Team"]=="Finance"] #Team i Finance olanları getirir.
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2022-12-29 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-12-29 13:00:00  138705    9.340
# 7          NaN  Female 2015-07-20 2022-12-29 10:43:00   45906   11.598
# 14    Kimberly  Female 1999-01-14 2022-12-29 07:13:00   41426   14.543
# 46       Bruce    Male 2009-11-28 2022-12-29 22:47:00  114796    6.796
# ..         ...     ...        ...                 ...     ...      ...
# 907  Elizabeth  Female 1998-07-27 2022-12-29 11:12:00  137144   10.081
# 954        Joe    Male 1980-01-19 2022-12-29 16:06:00  119667    1.148
# 987     Gloria  Female 2014-12-08 2022-12-29 05:08:00  136709   10.331
# 992    Anthony    Male 2011-10-16 2022-12-29 08:35:00  112769   11.625
# 996    Phillip    Male 1984-01-31 2022-12-29 06:30:00   42392   19.675
#
#      Senior Management     Team
# 2                False  Finance
# 3                 True  Finance
# ...

# %%
condition1=emp_df["Gender"]=="Male" # Gender ı male olanları değişkene atayıp dataframe den öyle sorgulatmış
emp_df[condition1]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2022-12-29 12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31 2022-12-29 06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04 2022-12-29 13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24 2022-12-29 16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18 2022-12-29 01:35:00  115163   10.125
# ..         ...    ...        ...                 ...     ...      ...
# 994     George   Male 2013-06-21 2022-12-29 17:47:00   98874    4.479
# 996    Phillip   Male 1984-01-31 2022-12-29 06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20 2022-12-29 12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20 2022-12-29 16:45:00   60500   11.985
# 999     Albert   Male 2012-05-15 2022-12-29 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
emp_df[emp_df["Senior Management"]] #boolean alanda true olanları getirir
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-12-29 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2022-12-29 06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04 2022-12-29 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-12-29 16:47:00  101004    1.389
# 6         Ruby  Female 1987-08-17 2022-12-29 16:20:00   65476   10.012
# ..         ...     ...        ...                 ...     ...      ...
# 991       Rose  Female 2002-08-25 2022-12-29 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2022-12-29 08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15 2022-12-29 15:53:00   56450   19.040
# 994     George    Male 2013-06-21 2022-12-29 17:47:00   98874    4.479
# 999     Albert    Male 2012-05-15 2022-12-29 18:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# ...

# %%
emp_df[~emp_df["Senior Management"]] #boolean alanda false olanları getirir
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2022-12-29 11:17:00  130590   11.858
# 5       Dennis    Male 1987-04-18 2022-12-29 01:35:00  115163   10.125
# 13        Gary    Male 2008-01-27 2022-12-29 23:40:00  109831    5.831
# 15     Lillian  Female 2016-06-05 2022-12-29 06:09:00   59414    1.256
# 16      Jeremy    Male 2010-09-21 2022-12-29 05:56:00   90370    7.369
# ..         ...     ...        ...                 ...     ...      ...
# 989     Justin     NaN 1991-02-10 2022-12-29 16:58:00   38344    3.794
# 995      Henry     NaN 2014-11-23 2022-12-29 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2022-12-29 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2022-12-29 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2022-12-29 16:45:00   60500   11.985
#
#      Senior Management                  Team
# 2                False               Finance
# ...

# %%
emp_df[emp_df["Team"]!="Finance"] #Teami Finance değilse getirir
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-12-29 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2022-12-29 06:53:00   61933    4.170
# 4        Larry    Male 1998-01-24 2022-12-29 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2022-12-29 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2022-12-29 16:20:00   65476   10.012
# ..         ...     ...        ...                 ...     ...      ...
# 994     George    Male 2013-06-21 2022-12-29 17:47:00   98874    4.479
# 995      Henry     NaN 2014-11-23 2022-12-29 06:09:00  132483   16.655
# 997    Russell    Male 2013-05-20 2022-12-29 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2022-12-29 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2022-12-29 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
emp_df[emp_df["Salary"]>=100000]
#Salary si 100000 den fazla olanları getirir
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2022-12-29 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-12-29 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-12-29 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2022-12-29 01:35:00  115163   10.125
# 9      Frances  Female 2002-08-08 2022-12-29 06:51:00  139852    7.524
# ..         ...     ...        ...                 ...     ...      ...
# 990      Robin  Female 1987-07-24 2022-12-29 13:35:00  100765   10.982
# 991       Rose  Female 2002-08-25 2022-12-29 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2022-12-29 08:35:00  112769   11.625
# 995      Henry     NaN 2014-11-23 2022-12-29 06:09:00  132483   16.655
# 999     Albert    Male 2012-05-15 2022-12-29 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 2                False               Finance
# ...

# %%
len(emp_df[emp_df["Salary"]>=100000]) #kaç kişi olduğunu bulmak için
# Out:
# 409

# %%
emp_df[emp_df["Start Date"]>"1990-01-01"] #start date i girilen tarihten sonra olanları alır
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-12-29 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2022-12-29 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2022-12-29 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-12-29 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-12-29 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 994     George    Male 2013-06-21 2022-12-29 17:47:00   98874    4.479
# 995      Henry     NaN 2014-11-23 2022-12-29 06:09:00  132483   16.655
# 997    Russell    Male 2013-05-20 2022-12-29 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2022-12-29 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2022-12-29 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
emp_df[(emp_df["Gender"]=="Male") & (emp_df["Team"]=="Finance")] #birden fazla şart VE
#Male ve finance da çalışanlar
# Out:
#       First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 3          Jerry   Male 2005-03-04 2022-12-29 13:00:00  138705    9.340
# 46         Bruce   Male 2009-11-28 2022-12-29 22:47:00  114796    6.796
# 56          Carl   Male 2006-05-03 2022-12-29 17:55:00  130276   16.084
# 68          Jose   Male 2004-10-30 2022-12-29 13:39:00   84834   14.330
# 83         Shawn   Male 2005-09-23 2022-12-29 02:55:00  148115    6.539
# 117       Steven   Male 1995-03-01 2022-12-29 15:03:00  109095    9.494
# 200         Gary   Male 1987-08-12 2022-12-29 00:04:00   89661    8.525
# 205      Brandon   Male 2006-03-27 2022-12-29 17:54:00  115711    8.012
# 219        Billy   Male 1995-03-13 2022-12-29 12:05:00  120444    7.768
# 222        Jason   Male 1999-10-17 2022-12-29 22:09:00   78417    3.067
# 241       Walter   Male 1983-07-06 2022-12-29 23:54:00  127813    5.961
# 286         Todd   Male 1984-02-02 2022-12-29 10:13:00   69989   10.985
# ...

# %%
cond1=emp_df["Gender"]=="Male"
cond2=emp_df["Team"]=="Finance"
emp_df[cond1&cond2] #birden fazla şartı bu şekilde de yazabiliriz
# Out:
#       First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 3          Jerry   Male 2005-03-04 2022-12-29 13:00:00  138705    9.340
# 46         Bruce   Male 2009-11-28 2022-12-29 22:47:00  114796    6.796
# 56          Carl   Male 2006-05-03 2022-12-29 17:55:00  130276   16.084
# 68          Jose   Male 2004-10-30 2022-12-29 13:39:00   84834   14.330
# 83         Shawn   Male 2005-09-23 2022-12-29 02:55:00  148115    6.539
# 117       Steven   Male 1995-03-01 2022-12-29 15:03:00  109095    9.494
# 200         Gary   Male 1987-08-12 2022-12-29 00:04:00   89661    8.525
# 205      Brandon   Male 2006-03-27 2022-12-29 17:54:00  115711    8.012
# 219        Billy   Male 1995-03-13 2022-12-29 12:05:00  120444    7.768
# 222        Jason   Male 1999-10-17 2022-12-29 22:09:00   78417    3.067
# 241       Walter   Male 1983-07-06 2022-12-29 23:54:00  127813    5.961
# 286         Todd   Male 1984-02-02 2022-12-29 10:13:00   69989   10.985
# ...

# %%
cond1=emp_df["Team"]=="Marketing" #veya
cond2=emp_df["Start Date"]=="1985-01-01"
emp_df[cond1 | cond2]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-12-29 12:42:00   97308    6.945
# 21     Matthew    Male 1995-09-05 2022-12-29 02:12:00  100612   13.645
# 26       Craig    Male 2000-02-27 2022-12-29 07:45:00   37598    7.757
# 43     Marilyn  Female 1980-12-07 2022-12-29 03:16:00   73524    5.207
# 62         NaN  Female 2007-06-12 2022-12-29 17:25:00   58112   19.414
# ..         ...     ...        ...                 ...     ...      ...
# 942       Lori  Female 2015-11-20 2022-12-29 13:15:00   75498    6.537
# 947        NaN    Male 2012-07-30 2022-12-29 15:07:00  107351    5.329
# 986      Donna  Female 1982-11-26 2022-12-29 07:04:00   82871   17.999
# 991       Rose  Female 2002-08-25 2022-12-29 05:12:00  134505   11.051
# 994     George    Male 2013-06-21 2022-12-29 17:47:00   98874    4.479
#
#      Senior Management       Team
# 0                 True  Marketing
# 21               False  Marketing
# ...

# %%
cond1=emp_df["First Name"]=="Robert"
cond2=emp_df["Team"]=="Client Services"
cond3=emp_df["Start Date"]>"2016-06-01"
emp_df[(cond1&cond2) | cond3] #hangi ikisinin önce çalışacağını belirleyeceksek -beraber çalışan şartları- paranteze almalıyız
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 15     Lillian  Female 2016-06-05 2022-12-29 06:09:00   59414    1.256
# 98        Tina  Female 2016-06-16 2022-12-29 19:47:00  100705   16.961
# 387     Robert    Male 1994-10-29 2022-12-29 04:26:00  123294   19.894
# 451      Terry     NaN 2016-07-15 2022-12-29 00:29:00  140002   19.490
#
#      Senior Management             Team
# 15               False          Product
# 98                True        Marketing
# 387              False  Client Services
# 451               True        Marketing

# %%
emp_df[(emp_df["Team"]=="Marketing") | (emp_df["Team"]=="Finance") |(emp_df["Team"]=="Product")]
# Marketing veya Finance veya product da çalışanları getir
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-12-29 12:42:00   97308    6.945
# 2        Maria  Female 1993-04-23 2022-12-29 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-12-29 13:00:00  138705    9.340
# 6         Ruby  Female 1987-08-17 2022-12-29 16:20:00   65476   10.012
# 7          NaN  Female 2015-07-20 2022-12-29 10:43:00   45906   11.598
# ..         ...     ...        ...                 ...     ...      ...
# 991       Rose  Female 2002-08-25 2022-12-29 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2022-12-29 08:35:00  112769   11.625
# 994     George    Male 2013-06-21 2022-12-29 17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 2022-12-29 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2022-12-29 12:39:00   96914    1.421
#
#      Senior Management       Team
# 0                 True  Marketing
# 2                False    Finance
# ...

# %%
emp_df[emp_df["Team"].isin(["Marketing","Finance","Product"])] #Marketing Finance Product ta çalışanları getirir
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-12-29 12:42:00   97308    6.945
# 2        Maria  Female 1993-04-23 2022-12-29 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-12-29 13:00:00  138705    9.340
# 6         Ruby  Female 1987-08-17 2022-12-29 16:20:00   65476   10.012
# 7          NaN  Female 2015-07-20 2022-12-29 10:43:00   45906   11.598
# ..         ...     ...        ...                 ...     ...      ...
# 991       Rose  Female 2002-08-25 2022-12-29 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2022-12-29 08:35:00  112769   11.625
# 994     George    Male 2013-06-21 2022-12-29 17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 2022-12-29 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2022-12-29 12:39:00   96914    1.421
#
#      Senior Management       Team
# 0                 True  Marketing
# 2                False    Finance
# ...

# %%
emp_df[emp_df["Team"].isnull()] #Team i null olanları getirir
# Out:
#       First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1         Thomas    Male 1996-03-31 2022-12-29 06:53:00   61933    4.170
# 10        Louise  Female 1980-08-12 2022-12-29 09:01:00   63241   15.132
# 23           NaN    Male 2012-06-14 2022-12-29 16:19:00  125792    5.042
# 32           NaN    Male 1998-08-21 2022-12-29 14:27:00  122340    6.417
# 91         James     NaN 2005-01-26 2022-12-29 23:00:00  128771    8.309
# 109  Christopher    Male 2000-04-22 2022-12-29 10:15:00   37919   11.449
# 139          NaN  Female 1990-10-03 2022-12-29 01:08:00  132373   10.527
# 199     Jonathan    Male 2009-07-17 2022-12-29 08:15:00  130581   16.736
# 258      Michael    Male 2002-01-24 2022-12-29 03:04:00   43586   12.659
# 290       Jeremy    Male 1988-06-14 2022-12-29 18:20:00  129460   13.657
# 314        Bobby    Male 1996-03-31 2022-12-29 17:40:00  112117    6.338
# 367       Edward    Male 1989-08-04 2022-12-29 06:06:00   66067   10.957
# ...

# %%
emp_df[emp_df["Team"].notnull()] #notnull da null olmayanları getirir
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-12-29 12:42:00   97308    6.945
# 2        Maria  Female 1993-04-23 2022-12-29 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-12-29 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-12-29 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2022-12-29 01:35:00  115163   10.125
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2022-12-29 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2022-12-29 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2022-12-29 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2022-12-29 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2022-12-29 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
emp_df[emp_df["Salary"].between(40000,60000,inclusive="right")] 
#between--> inclusive:{both,neither,left,right} dahil durumu AŞIRI ÖNEMLİ
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 327      Aaron    Male 1994-01-29 2022-12-29 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2022-12-29 14:53:00   52119   11.343
# 538       Adam    Male 2010-10-08 2022-12-29 21:53:00   45181    3.491
# 53        Alan     NaN 2014-03-03 2022-12-29 13:28:00   40341   17.578
# 610       Alan    Male 2012-02-17 2022-12-29 00:26:00   41453   10.084
# ..         ...     ...        ...                 ...     ...      ...
# 257        NaN    Male 1999-11-25 2022-12-29 06:16:00   42676   15.517
# 267        NaN    Male 2005-02-04 2022-12-29 13:01:00   40451   16.044
# 567        NaN  Female 1980-04-01 2022-12-29 20:04:00   48141   12.605
# 773        NaN    Male 1986-10-24 2022-12-29 09:23:00   47176   10.736
# 785        NaN  Female 1982-07-24 2022-12-29 00:00:00   57811    8.941
#
#      Senior Management             Team
# 327               True        Marketing
# ...

# %%
emp_df[emp_df["Start Date"].between("1985-01-01","1995-01-01")]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-12-29 12:42:00   97308    6.945
# 2        Maria  Female 1993-04-23 2022-12-29 11:17:00  130590   11.858
# 5       Dennis    Male 1987-04-18 2022-12-29 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2022-12-29 16:20:00   65476   10.012
# 17       Shawn    Male 1986-12-07 2022-12-29 19:45:00  111737    6.414
# ..         ...     ...        ...                 ...     ...      ...
# 970      Alice  Female 1988-09-03 2022-12-29 20:54:00   63571   15.397
# 976     Denise  Female 1992-10-19 2022-12-29 05:42:00  137954    4.195
# 981      James    Male 1993-01-15 2022-12-29 17:19:00  148985   19.280
# 989     Justin     NaN 1991-02-10 2022-12-29 16:58:00   38344    3.794
# 990      Robin  Female 1987-07-24 2022-12-29 13:35:00  100765   10.982
#
#      Senior Management             Team
# 0                 True        Marketing
# ...

# %%
emp_df[emp_df["Last Login Time"].between("08:30 AM","12:30 PM", inclusive="left")]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2022-12-29 11:17:00  130590   11.858
# 7          NaN  Female 2015-07-20 2022-12-29 10:43:00   45906   11.598
# 10      Louise  Female 1980-08-12 2022-12-29 09:01:00   63241   15.132
# 18       Diana  Female 1981-10-23 2022-12-29 10:27:00  132940   19.082
# 33        Jean  Female 1993-12-18 2022-12-29 09:07:00  119082   16.180
# ..         ...     ...        ...                 ...     ...      ...
# 963        Ann  Female 1994-09-23 2022-12-29 11:15:00   89443   17.940
# 977      Sarah  Female 1995-12-04 2022-12-29 09:16:00  124566    5.949
# 982       Rose  Female 1982-04-06 2022-12-29 10:43:00   91411    8.639
# 988      Alice  Female 2004-10-05 2022-12-29 09:34:00   47638   11.209
# 992    Anthony    Male 2011-10-16 2022-12-29 08:35:00  112769   11.625
#
#      Senior Management                  Team
# 2                False               Finance
# ...

# %%
emp_df.sort_values("First Name",inplace=True) 
#sort_values ile belirtilen column a göre sıralama yapılır.ascending i true olduğu için küçükten büyüğe doğru sıraladı
emp_df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2022-12-29 10:20:00   61602   11.849
# 327      Aaron    Male 1994-01-29 2022-12-29 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2022-12-29 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2022-12-29 19:39:00   63126   18.424
# 137       Adam    Male 2011-05-21 2022-12-29 01:45:00   95327   15.120
# ..         ...     ...        ...                 ...     ...      ...
# 902        NaN    Male 2001-05-23 2022-12-29 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2022-12-29 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2022-12-29 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2022-12-29 15:07:00  107351    5.329
# 951        NaN  Female 2010-09-14 2022-12-29 05:19:00  143638    9.662
#
#      Senior Management             Team
# 101               True        Marketing
# ...

# %%
emp_df["First Name"].duplicated() 
#birden fazla olanları işaretler ya ilkini tutar ya sonunu tutar default olarak ilki tutar keep ile bunu değiştirebiliriz.
# Out:
# 101    False
# 327     True
# 440     True
# 937     True
# 137    False
#        ...
# 902     True
# 925     True
# 946     True
# 947     True
# 951     True
# Name: First Name, Length: 1000, dtype: bool

# %%
emp_df["First Name"].duplicated(keep="last") #sonuncusunu false olarak döndürür
# Out:
# 101     True
# 327     True
# 440     True
# 937    False
# 137     True
#        ...
# 902     True
# 925     True
# 946     True
# 947     True
# 951    False
# Name: First Name, Length: 1000, dtype: bool

# %%
emp_df[emp_df["First Name"].duplicated()]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 327      Aaron    Male 1994-01-29 2022-12-29 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2022-12-29 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2022-12-29 19:39:00   63126   18.424
# 141       Adam    Male 1990-12-24 2022-12-29 20:57:00  110194   14.727
# 302       Adam    Male 2007-07-05 2022-12-29 11:59:00   71276    5.027
# ..         ...     ...        ...                 ...     ...      ...
# 902        NaN    Male 2001-05-23 2022-12-29 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2022-12-29 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2022-12-29 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2022-12-29 15:07:00  107351    5.329
# 951        NaN  Female 2010-09-14 2022-12-29 05:19:00  143638    9.662
#
#      Senior Management             Team
# 327               True        Marketing
# ...

# %%
emp_df[~emp_df["First Name"].duplicated()] # ~not demek bu işaret  
#dublicated olmayanları yani false dönen değerleri getirdi
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2022-12-29 10:20:00   61602   11.849
# 137       Adam    Male 2011-05-21 2022-12-29 01:45:00   95327   15.120
# 300       Alan    Male 1988-06-26 2022-12-29 03:54:00  111786    3.592
# 372     Albert    Male 1997-02-01 2022-12-29 16:20:00   67827   19.717
# 988      Alice  Female 2004-10-05 2022-12-29 09:34:00   47638   11.209
# ..         ...     ...        ...                 ...     ...      ...
# 433      Wanda  Female 2008-07-20 2022-12-29 13:44:00   65362    7.132
# 177      Wayne    Male 2012-04-07 2022-12-29 08:00:00  102652   14.085
# 820    William    Male 1993-11-18 2022-12-29 12:27:00   54058    5.182
# 450     Willie    Male 2009-08-22 2022-12-29 13:03:00   55038   19.691
# 7          NaN  Female 2015-07-20 2022-12-29 10:43:00   45906   11.598
#
#      Senior Management             Team
# 101               True        Marketing
# ...

# %%
emp_df[~emp_df["First Name"].duplicated(keep=False)] #keep=false hiçbirini tutma demek
#unique olanları dönüyor keep sayesinde
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2022-12-29 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2022-12-29 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2022-12-29 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2022-12-29 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2022-12-29 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2022-12-29 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2022-12-29 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2022-12-29 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2022-12-29 10:30:00  132839   17.463
#
#      Senior Management                  Team
# 8                 True           Engineering
# 688               True                 Legal
# 190              False               Finance
# 887              False                 Legal
# ...

# %%
len(emp_df.drop_duplicates())#kayıt bazında aynı kayıt var mı bakar siler
# Out:
# 1000

# %%
emp_df.drop_duplicates(subset="First Name")# First Name columndaki aynı kayıtlara bakar ve siler
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2022-12-29 10:20:00   61602   11.849
# 137       Adam    Male 2011-05-21 2022-12-29 01:45:00   95327   15.120
# 300       Alan    Male 1988-06-26 2022-12-29 03:54:00  111786    3.592
# 372     Albert    Male 1997-02-01 2022-12-29 16:20:00   67827   19.717
# 988      Alice  Female 2004-10-05 2022-12-29 09:34:00   47638   11.209
# ..         ...     ...        ...                 ...     ...      ...
# 433      Wanda  Female 2008-07-20 2022-12-29 13:44:00   65362    7.132
# 177      Wayne    Male 2012-04-07 2022-12-29 08:00:00  102652   14.085
# 820    William    Male 1993-11-18 2022-12-29 12:27:00   54058    5.182
# 450     Willie    Male 2009-08-22 2022-12-29 13:03:00   55038   19.691
# 7          NaN  Female 2015-07-20 2022-12-29 10:43:00   45906   11.598
#
#      Senior Management             Team
# 101               True        Marketing
# ...

# %%
emp_df.drop_duplicates(subset=["First Name","Team"]) #adı ve takımı aynı olanları siler
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2022-12-29 10:20:00   61602   11.849
# 440      Aaron    Male 1990-07-22 2022-12-29 14:53:00   52119   11.343
# 137       Adam    Male 2011-05-21 2022-12-29 01:45:00   95327   15.120
# 141       Adam    Male 1990-12-24 2022-12-29 20:57:00  110194   14.727
# 302       Adam    Male 2007-07-05 2022-12-29 11:59:00   71276    5.027
# ..         ...     ...        ...                 ...     ...      ...
# 149        NaN  Female 2014-08-17 2022-12-29 14:00:00   86230    8.578
# 157        NaN  Female 2005-07-27 2022-12-29 08:32:00   79536   14.443
# 269        NaN  Female 1992-08-02 2022-12-29 20:35:00  145316   18.517
# 329        NaN    Male 2010-01-27 2022-12-29 02:57:00   87760   14.987
# 481        NaN  Female 2013-04-27 2022-12-29 06:40:00   93847    1.085
#
#      Senior Management                  Team
# 101               True             Marketing
# ...

# %%
emp_df["Gender"].unique() #GENDER DA geçen unique biricik değerleri verir
# Out:
# ['Male', NaN, 'Female']
# Categories (2, object): ['Female', 'Male']

# %%
emp_df["First Name"].unique() #unique olan isimleri verir
# Out:
# array(['Aaron', 'Adam', 'Alan', 'Albert', 'Alice', 'Amanda', 'Amy',
#        'Andrea', 'Andrew', 'Angela', 'Ann', 'Anna', 'Anne', 'Annie',
#        'Anthony', 'Antonio', 'Arthur', 'Ashley', 'Barbara', 'Benjamin',
#        'Betty', 'Beverly', 'Billy', 'Bobby', 'Bonnie', 'Brandon',
#        'Brenda', 'Brian', 'Bruce', 'Carl', 'Carlos', 'Carol', 'Carolyn',
#        'Catherine', 'Charles', 'Cheryl', 'Chris', 'Christina',
#        'Christine', 'Christopher', 'Clarence', 'Craig', 'Cynthia',
#        'Daniel', 'David', 'Deborah', 'Debra', 'Denise', 'Dennis', 'Diana',
#        'Diane', 'Donald', 'Donna', 'Doris', 'Dorothy', 'Douglas', 'Earl',
#        'Edward', 'Elizabeth', 'Emily', 'Eric', 'Ernest', 'Eugene',
#        'Evelyn', 'Frances', 'Frank', 'Fred', 'Gary', 'George', 'Gerald',
#        'Gloria', 'Gregory', 'Harold', 'Harry', 'Heather', 'Helen',
#        'Henry', 'Howard', 'Irene', 'Jack', 'Jacqueline', 'James', 'Jane',
# ...

# %%
len(emp_df["First Name"].unique()) #uzunluğu
# Out:
# 201

# %%
emp_df["First Name"].nunique() 
#dropna sı default olarak True dur ve null ları saymaz hepsini saysın istersek dropna sını false yapmalıyız
# Out:
# 200

# %%
emp_df["First Name"].nunique(dropna=False)
# Out:
# 201

# %%
emp_jb=pd.read_csv("resources/resources/jamesbond.csv")
emp_jb
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
emp_jb=pd.read_csv("resources/resources/jamesbond.csv",index_col="Film")
emp_jb
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
emp_jb=pd.read_csv("resources/resources/jamesbond.csv")
emp_jb
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
emp_jb.set_index(keys="Film") #set_index ile istediğmiz yeri indexleyebiliriz index_col gibi
#drop=True filmi sağdan siler ekranda sadece bi tane film columnu gösterilir
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
emp_jb.set_index(keys="Film",inplace=True)
emp_jb
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
emp_jb.reset_index() #reset_index verdiğimiz indexi silmemize ilk duruma döndürmemizi sağlar 
#artık index film columnu değil 
#inplace = True dememiz gerekiyor
#drop=True dememiz de gerek burda default u false
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
emp_jb.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
emp_jb.reset_index(drop=True) # drop->index olan columnu dateframe den çıkarır
# Out:
#     Year           Actor            Director  Box Office  Budget  \
# 0   1962    Sean Connery       Terence Young       448.8     7.0
# 1   1963    Sean Connery       Terence Young       543.8    12.6
# 2   1964    Sean Connery        Guy Hamilton       820.4    18.6
# 3   1965    Sean Connery       Terence Young       848.1    41.9
# 4   1967     David Niven          Ken Hughes       315.0    85.0
# 5   1967    Sean Connery       Lewis Gilbert       514.2    59.9
# 6   1969  George Lazenby       Peter R. Hunt       291.5    37.3
# 7   1971    Sean Connery        Guy Hamilton       442.5    34.7
# 8   1973     Roger Moore        Guy Hamilton       460.3    30.8
# 9   1974     Roger Moore        Guy Hamilton       334.0    27.7
# 10  1977     Roger Moore       Lewis Gilbert       533.0    45.1
# 11  1979     Roger Moore       Lewis Gilbert       535.0    91.5
# 12  1981     Roger Moore           John Glen       449.4    60.2
# ...

# %%
emp_jb.reset_index(inplace=True) #reset indexe dikkat et drop u True olursa column kaybına uğrarız
emp_jb
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
emp_jb.set_index("Film",inplace=True) #indexi film columnu atadığımız için film isimlerini kullanabiliriz

# %%
emp_jb.loc["Diamonds Are Forever"] #loc ile Diamonds Are Forever indexinin olduğu satırı getirir
# Out:
# Year                         1971
# Actor                Sean Connery
# Director             Guy Hamilton
# Box Office                  442.5
# Budget                       34.7
# Bond Actor Salary             5.8
# Name: Diamonds Are Forever, dtype: object

# %%
emp_jb.loc["yufus"] #olmayan kayıt sorgulamada keyError fırlatır
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:160, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:201, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:209, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:107, in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 'yufus'
#
# ...

# %%
emp_jb.loc["Diamonds Are Forever":"Moonraker":2] #location veririz
# Out:
#                              Year         Actor       Director  Box Office  \
# Film
# Diamonds Are Forever         1971  Sean Connery   Guy Hamilton       442.5
# The Man with the Golden Gun  1974   Roger Moore   Guy Hamilton       334.0
# Moonraker                    1979   Roger Moore  Lewis Gilbert       535.0
#
#                              Budget  Bond Actor Salary
# Film
# Diamonds Are Forever           34.7                5.8
# The Man with the Golden Gun    27.7                NaN
# Moonraker                      91.5                NaN

# %%
emp_jb.loc["Diamonds Are Forever":]
# Out:
#                              Year           Actor            Director  \
# Film
# Diamonds Are Forever         1971    Sean Connery        Guy Hamilton
# Live and Let Die             1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me         1977     Roger Moore       Lewis Gilbert
# Moonraker                    1979     Roger Moore       Lewis Gilbert
# For Your Eyes Only           1981     Roger Moore           John Glen
# Never Say Never Again        1983    Sean Connery      Irvin Kershner
# Octopussy                    1983     Roger Moore           John Glen
# A View to a Kill             1985     Roger Moore           John Glen
# The Living Daylights         1987  Timothy Dalton           John Glen
# Licence to Kill              1989  Timothy Dalton           John Glen
# GoldenEye                    1995  Pierce Brosnan     Martin Campbell
# ...

# %%
emp_jb.loc[:"Diamonds Are Forever"]
# Out:
#                                  Year           Actor       Director  \
# Film
# Dr. No                           1962    Sean Connery  Terence Young
# From Russia with Love            1963    Sean Connery  Terence Young
# Goldfinger                       1964    Sean Connery   Guy Hamilton
# Thunderball                      1965    Sean Connery  Terence Young
# Casino Royale                    1967     David Niven     Ken Hughes
# You Only Live Twice              1967    Sean Connery  Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery   Guy Hamilton
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Dr. No                                448.8     7.0                0.6
# From Russia with Love                 543.8    12.6                1.6
# Goldfinger                            820.4    18.6                3.2
# ...

# %%
emp_jb.loc[["Diamonds Are Forever","Moonraker"]] #tek kayıtta seri birden fazla kayıtta dataframe döndürür
# Out:
#                       Year         Actor       Director  Box Office  Budget  \
# Film
# Diamonds Are Forever  1971  Sean Connery   Guy Hamilton       442.5    34.7
# Moonraker             1979   Roger Moore  Lewis Gilbert       535.0    91.5
#
#                       Bond Actor Salary
# Film
# Diamonds Are Forever                5.8
# Moonraker                           NaN

# %%
jb_df=pd.read_csv("resources/resources/jamesbond.csv")
jb_df
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
jb_df.iloc[0] #loc ta sözel iloc da index location veriyoruz
#index sayıyken loc kullanamayız ama diğer türlü iloc ve locu kullanabiliriz
#loc ta yaptığımız her şey iloc da da geçerli
# Out:
# Film                        Dr. No
# Year                          1962
# Actor                 Sean Connery
# Director             Terence Young
# Box Office                   448.8
# Budget                         7.0
# Bond Actor Salary              0.6
# Name: 0, dtype: object

# %%
jb_df.iloc[[3,5,7]]
# Out:
#                    Film  Year         Actor       Director  Box Office  \
# 3           Thunderball  1965  Sean Connery  Terence Young       848.1
# 5   You Only Live Twice  1967  Sean Connery  Lewis Gilbert       514.2
# 7  Diamonds Are Forever  1971  Sean Connery   Guy Hamilton       442.5
#
#    Budget  Bond Actor Salary
# 3    41.9                4.7
# 5    59.9                4.4
# 7    34.7                5.8

# %%
jb_df=pd.read_csv("resources/resources/jamesbond.csv",index_col="Film")
jb_df.sort_index(inplace=True)
jb_df
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
jb_df.loc["A View to a Kill",["Actor","Budget"]] #filmlerin actorunu getirir
# Out:
# Actor     Roger Moore
# Budget           54.5
# Name: A View to a Kill, dtype: object

# %%
jb_df.loc[["A View to a Kill","Thunderball"],["Actor","Budget"]]
# Out:
#                          Actor  Budget
# Film
# A View to a Kill   Roger Moore    54.5
# Thunderball       Sean Connery    41.9

# %%
jb_df.loc["A View to a Kill","Actor":"Budget"] #actor den budget column a kadar getir
# Out:
# Actor         Roger Moore
# Director        John Glen
# Box Office          275.2
# Budget               54.5
# Name: A View to a Kill, dtype: object

# %%
jb_df.loc["A View to a Kill":,"Actor":"Budget"] #A View to a Kill satırından sonuna kadar-actor den budget column a kadar getir
# Out:
#                                           Actor            Director  \
# Film
# A View to a Kill                    Roger Moore           John Glen
# Casino Royale                      Daniel Craig     Martin Campbell
# Casino Royale                       David Niven          Ken Hughes
# Diamonds Are Forever               Sean Connery        Guy Hamilton
# Die Another Day                  Pierce Brosnan        Lee Tamahori
# Dr. No                             Sean Connery       Terence Young
# For Your Eyes Only                  Roger Moore           John Glen
# From Russia with Love              Sean Connery       Terence Young
# GoldenEye                        Pierce Brosnan     Martin Campbell
# Goldfinger                         Sean Connery        Guy Hamilton
# Licence to Kill                  Timothy Dalton           John Glen
# Live and Let Die                    Roger Moore        Guy Hamilton
# Moonraker                           Roger Moore       Lewis Gilbert
# ...

# %%
jb_df.iloc[0,2] #satır,sutün-> 0.satırın 2.sütunu
# Out:
# 'John Glen'

# %%
jb_df.iloc[:,2:5] #tüm satırları al 2.sütundan 5.sütuna kadar göster
# Out:
#                                            Director  Box Office  Budget
# Film
# A View to a Kill                          John Glen       275.2    54.5
# Casino Royale                       Martin Campbell       581.5   145.3
# Casino Royale                            Ken Hughes       315.0    85.0
# Diamonds Are Forever                   Guy Hamilton       442.5    34.7
# Die Another Day                        Lee Tamahori       465.4   154.2
# Dr. No                                Terence Young       448.8     7.0
# For Your Eyes Only                        John Glen       449.4    60.2
# From Russia with Love                 Terence Young       543.8    12.6
# GoldenEye                           Martin Campbell       518.5    76.9
# Goldfinger                             Guy Hamilton       820.4    18.6
# Licence to Kill                           John Glen       250.9    56.7
# Live and Let Die                       Guy Hamilton       460.3    30.8
# ...
